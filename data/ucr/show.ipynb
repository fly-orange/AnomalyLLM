# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
ANOMALY_ARCHIVE_DATA_FAMILY_TO_DATA_TYPE = {
    'ECG': [
        'sddb40', 
        'BIDMC1', 
        'CHARISfive', 
        'CHARISten', 
        'ECG', 
        'sddb49', 
        'longtermecg', 
        'ltstdbs30791', 
        'sel840mECG', 
        's20101m', 
        'qtdbSel100', 
        'apneaecg', 
        'STAFFIIIDatabase', 
        'Fantasia'],
    'Gait': [
        'weallwalk', 
        'taichidbS0715Master', 
        'park3m', 
        'gait', 
        'GP711MarkerLFM5z'],
    'PowerDemand': [
        'PowerDemand', 
        'Italianpowerdemand'],
    'EPG': [
        'insectEPG', 
        'Lab2Cmac011215EPG'],
    'ABP': [
        'tiltAPB', 
        'tilt127', 
        'InternalBleeding'],
    'RESP': [
        'resperation'],
    'Acceleration': [
        'WalkingAceleration', 
        'MesoplodonDensirostris'],
    'NASA': [
        'MARS'],
    'AirTemperature': [
        'CIMIS44AirTemperature']
}
s={}
for key in ANOMALY_ARCHIVE_DATA_FAMILY_TO_DATA_TYPE.keys():
    s[key] = len(os.listdir(f"UCR_Anomaly_ClassData/{key}"))
print(s)
# Out:
# {'ECG': 91, 'Gait': 33, 'PowerDemand': 11, 'EPG': 25, 'ABP': 42, 'RESP': 17, 'Acceleration': 7, 'NASA': 11, 'AirTemperature': 13}

# %%
import numpy as np
data = np.loadtxt('UCR_Anomaly_ClassData/Acceleration/054_UCR_Anomaly_DISTORTEDWalkingAceleration5_2700_5920_5979.txt')
print(data.shape)
plt.figure(figsize=(10,2))
plt.plot(data)
plt.show()
# Out:
# (6684,)

# %%
data = np.loadtxt('UCR_Anomaly_ClassData/Acceleration/053_UCR_Anomaly_DISTORTEDWalkingAceleration1_1500_2764_2995.txt')
print(data.shape)
plt.figure(figsize=(10,2))
plt.plot(data)
plt.show()
# Out:
# (6684,)
